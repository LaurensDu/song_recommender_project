# %% [markdown]
# # The code for the "song recommender" app

# %%
# import relevant libraries
import requests # to download html code
from bs4 import BeautifulSoup # to navigate through the html code
import pandas as pd
import numpy as np
import re
import random
import config

# %%
top_100 = pd.read_csv("top_100.csv", index_col=False)

# %%
top_100.head()
# Out:
#    Unnamed: 0                                Artist        Song
# 0           0                           Miley Cyrus     Flowers
# 1           1                                   SZA   Kill Bill
# 2           2                         Morgan Wallen  Last Night
# 3           3                Sam Smith & Kim Petras      Unholy
# 4           4  Metro Boomin, The Weeknd & 21 Savage    Creepin'

# %%
# writing the song recommender function
def song_recommender():
    """Function that prompts the user for song input
    and checks whether it's in the top-100 csv file."""
    top_100 = pd.read_csv("top_100.csv")
    user_input = input("Please type in your favorite song: ")
    if user_input.lower() in map(str.lower, list(top_100["Song"])):
        print("Your song is in the current top-100.")
        random_song = random.choice(list(top_100["Song"]))
        artist = top_100.loc[top_100["Song"] == random_song, 'Artist'].to_string(index=False)
        print(f"\nHere is another song from the top-100 you might like: {random_song} by {artist}")
    else: 
        print("Your song is not in the current top-100. Let me give you a suggestion for another song.")

# %%
# writing the while loop that ensures the programme keeps running
while True:
    song_recommender()
    user_input = input("\nDo you want to input another song? yes/no: ")
    if user_input == "yes":
        continue
    elif user_input == "no":
        print("Your session has ended. Thank you for using our app!")
        break
    else:
        print("Please write either 'yes' or 'no'")
        continue
# Out:
# Please type in your favorite song: Flowers
# Your song is in the current top-100.
#
# Here is another song from the top-100 you might like: OMG by NewJeans
#
# Do you want to input another song? yes/no: no
# Your session has ended. Thank you for using our app!

# %% [markdown]
# # Creating the song database with audio features

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


# initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
# checking a playlist
playlist = sp.user_playlist_tracks("spotify", "27gN69ebwiJRtXEboL12Ih")
playlist["items"][0]
# Out:
# {'added_at': '2022-11-26T02:31:48Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/celsum76'},
#   'href': 'https://api.spotify.com/v1/users/celsum76',
#   'id': 'celsum76',
#   'type': 'user',
#   'uri': 'spotify:user:celsum76'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#      'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#      'id': '5M52tdBnJaKSvOpJGz8mfZ',
#      'name': 'Black Sabbath',
#      'type': 'artist',
#      'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1JA2UhLRbFRkmoh6Lz64KH'},
#    'href': 'https://api.spotify.com/v1/albums/1JA2UhLRbFRkmoh6Lz64KH',
#    'id': '1JA2UhLRbFRkmoh6Lz64KH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738c9131b3b0f5a4b9fdc5a0ac',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028c9131b3b0f5a4b9fdc5a0ac',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518c9131b3b0f5a4b9fdc5a0ac',
#      'width': 64}],
#    'name': 'Paranoid (Deluxe Edition)',
#    'release_date': '1970-09-18',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:1JA2UhLRbFRkmoh6Lz64KH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#     'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#     'id': '5M52tdBnJaKSvOpJGz8mfZ',
#     'name': 'Black Sabbath',
#     'type': 'artist',
#     'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#   'available_markets': [],
#   'disc_number': 1,
#   'duration_ms': 167720,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAJE7000057'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3q9G9SvgdfE1fxlvoDIb20'},
#   'href': 'https://api.spotify.com/v1/tracks/3q9G9SvgdfE1fxlvoDIb20',
#   'id': '3q9G9SvgdfE1fxlvoDIb20',
#   'is_local': False,
#   'name': 'Paranoid',
#   'popularity': 0,
#   'preview_url': None,
#   'track': True,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:3q9G9SvgdfE1fxlvoDIb20'},
#  'video_thumbnail': {'url': None}}

# %%
# function that retrieves the songs from a playlist
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# creating a list with playlists id's and defining the variable 'tracks' to store the results
playlist_ids = ["27gN69ebwiJRtXEboL12Ih", "37i9dQZF1DX4pUKG1kS0Ac", "37i9dQZF1DXbITWG1ZJKYt", "37i9dQZF1DXbSbnqxMTGx9", "37i9dQZF1DX8a1tdzq5tbM", "37i9dQZF1EQpj7X7UK8OOF", "37i9dQZF1EQqkOPvHGajmW", "17IFbN8moTMWsaK5S5qCyD", "5i1mrZvsI0IertAQSeveAL", "42eLtt8RUBboyXLmNQWU5a", "1h0CEZCm6IbFTbxThn6Xcs", "1yswYW9ONg19LAlBOv87qq", "4hKNssGmIVEcWu1MF7HzgN", "32BC2f8hmAUmvsQgr9Mzsm", "37i9dQZF1DX10zKzsJ2jva", "37i9dQZF1DWY7IeIP1cdjF", "37i9dQZF1DX3MU5XUozve7", "37i9dQZF1DWYV7OOaGhoH0", "37i9dQZF1DX9XIFQuFvzM4", "37i9dQZF1DX0QNpebF7rcL", "37i9dQZF1DWVJ0TKGKfzgP", "37i9dQZF1DX5uWybZqQtdt"]
tracks = []
# genres included: metal, guilty pleasures, jazz, reggae, dance, rock, indie, rap/hiphop, chill, classic, techno, dutch, latin, reggaeton, punk, folk/acoustic, soul, blues, funk, live music

# for loop that loops through the playlist ids and retrieves the song with the get_playlist_tracks function
for i in playlist_ids:
    tracks += get_playlist_tracks("spotify", i)

# %%
# checking how many tracks are in the Pandas dataframe
print(len(tracks))
# Out:
# 3218

# %%
# getting the audio features
list_of_audio_features = []
for item in range(len(tracks)):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
print(len(tracks))
# Out:
# 3218

# %%
songs_df = pd.DataFrame(list_of_audio_features)    
songs_df = songs_df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

songs_df
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.423   0.685    -9.651       0.0780      0.000063
# 1            0.324   0.991    -4.465       0.1970      0.002470
# 2            0.308   0.866    -5.671       0.0590      0.000739
# 3            0.453   0.905    -4.001       0.1150      0.360000
# 4            0.420   0.930    -5.583       0.0638      0.018900
# ...            ...     ...       ...          ...           ...
# 3213         0.275   0.421   -10.316       0.0333      0.979000
# 3214         0.548   0.958    -4.050       0.0663      0.019400
# 3215         0.582   0.485   -12.781       0.0326      0.349000
# 3216         0.631   0.714    -7.300       0.0362      0.151000
# 3217         0.444   0.956    -3.208       0.0736      0.213000
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.006420     0.133    0.328  162.780  3q9G9SvgdfE1fxlvoDIb20
# 1             0.008950     0.104    0.195  140.245  47FyQCd3TYLrZ9TU6MPaWK
# 2             0.001410     0.232    0.227  109.825  6p8eFfPw3nQkf37aT3AkmK
# 3             0.000569     0.260    0.474  137.571  2b9lp5A6CqSzwOrBfAFhof
# 4             0.006750     0.264    0.344   99.641  1s4Ie0cT6P73SRSfh3oyGW
# ...                ...       ...      ...      ...                     ...
# 3213          0.012800     0.972    0.188   87.837  79qy23rYYWcAezGahawuBT
# 3214          0.001320     0.938    0.161  117.988  0sLR4zxufrMibvjc2G5FEc
# 3215          0.624000     0.668    0.751  128.872  3GGt2kbKX4VFCs3VM5JcsH
# 3216          0.000146     0.083    0.614  103.999  0Klcv9pnAMm5UjNh6PcCJQ
# 3217          0.183000     0.957    0.269  119.370  2VVROOX0ibcw7PThGkAhiz
#
#       duration_ms
# 0          167720
# 1          166707
# 2          438120
# 3          296200
# 4          291373
# ...           ...
# 3213       294597
# 3214       306827
# 3215       314400
# 3216       337760
# 3217       421992
#
# [3218 rows x 11 columns]

# %% [markdown]
# # Scaling the audio features of the song database and requesting the user's song

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
import numpy as np

# %%
audio_features = songs_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "liveness", "valence", "tempo"]]

# %%
audio_features.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  liveness  \
# 0         0.423   0.685    -9.651       0.0780      0.000063     0.133
# 1         0.324   0.991    -4.465       0.1970      0.002470     0.104
# 2         0.308   0.866    -5.671       0.0590      0.000739     0.232
# 3         0.453   0.905    -4.001       0.1150      0.360000     0.260
# 4         0.420   0.930    -5.583       0.0638      0.018900     0.264
#
#    valence    tempo
# 0    0.328  162.780
# 1    0.195  140.245
# 2    0.227  109.825
# 3    0.474  137.571
# 4    0.344   99.641

# %%
scaler = StandardScaler()
scaler.fit(audio_features)
audio_features_scaled = scaler.transform(audio_features)
audio_features_scaled
# Out:
# array([[-0.77369778,  0.24300869, -0.10399474, ..., -0.34517753,
#         -0.56597282,  1.52134428],
#        [-1.31425177,  1.38071407,  0.80167917, ..., -0.50118198,
#         -1.06505036,  0.72889929],
#        [-1.40161403,  0.91596514,  0.59106545, ...,  0.1873894 ,
#         -0.94497156, -0.34082232],
#        ...,
#        [ 0.09446469, -0.5005896 , -0.65061243, ...,  2.53283566,
#          1.0213189 ,  0.32896688],
#        [ 0.36201161,  0.35083044,  0.30657976, ..., -0.61415073,
#          0.50723151, -0.54569405],
#        [-0.65903481,  1.25058437,  1.02119943, ...,  4.08750073,
#         -0.78736812, -0.00517167]])

# %%
kmeans = KMeans(n_clusters=8, random_state=1234)
kmeans.fit(audio_features_scaled)
# assign a cluster to each example
labels = kmeans.predict(audio_features_scaled)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(audio_features.to_numpy()[row_ix, 0], audio_features.to_numpy()[row_ix,1])
    pyplot.xlabel("energy")
    pyplot.ylabel("instrumentalness")
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(audio_features_scaled)
# clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    546
# 1    378
# 2    208
# 3    184
# 4    440
# 5    234
# 6    772
# 7    456
# dtype: int64

# %%
# saving with pickle
import pickle

# scaler = StandardScaler()
# model = KMeans()

with open("scaler_song_recommender", "wb") as f:
    pickle.dump(scaler,f)

with open("kmeans_song_recommender", "wb") as f:
    pickle.dump(kmeans,f)

# %%
# getting the scaled songs back into a Pandas dataframe
scaled_songs_df = pd.DataFrame(audio_features_scaled, columns=["danceability", "energy", "loudness", "speechiness", "acousticness", "liveness", "valence", "tempo"])
scaled_songs_df.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  liveness  \
# 0     -0.773698  0.243009 -0.103995     0.088107     -0.856718 -0.345178
# 1     -1.314252  1.380714  0.801679     1.896837     -0.849668 -0.501182
# 2     -1.401614  0.915965  0.591065    -0.200682     -0.854738  0.187389
# 3     -0.609894  1.060967  0.882711     0.650485      0.197369  0.338014
# 4     -0.790078  1.153917  0.606434    -0.127725     -0.801553  0.359532
#
#     valence     tempo
# 0 -0.565973  1.521344
# 1 -1.065050  0.728899
# 2 -0.944972 -0.340822
# 3 -0.018113  0.634868
# 4 -0.505933 -0.698943

# %%
scaled_songs_df
# Out:
#       danceability    energy  loudness  speechiness  acousticness  liveness  \
# 0        -0.773698  0.243009 -0.103995     0.088107     -0.856718 -0.345178
# 1        -1.314252  1.380714  0.801679     1.896837     -0.849668 -0.501182
# 2        -1.401614  0.915965  0.591065    -0.200682     -0.854738  0.187389
# 3        -0.609894  1.060967  0.882711     0.650485      0.197369  0.338014
# 4        -0.790078  1.153917  0.606434    -0.127725     -0.801553  0.359532
# ...            ...       ...       ...          ...           ...       ...
# 3213     -1.581799 -0.738541 -0.220129    -0.591307      2.010129  4.168193
# 3214     -0.091180  1.258020  0.874154    -0.089726     -0.800088  3.985291
# 3215      0.094465 -0.500590 -0.650612    -0.601946      0.165155  2.532836
# 3216      0.362012  0.350830  0.306580    -0.547228     -0.414694 -0.614151
# 3217     -0.659035  1.250584  1.021199     0.021230     -0.233125  4.087501
#
#        valence     tempo
# 0    -0.565973  1.521344
# 1    -1.065050  0.728899
# 2    -0.944972 -0.340822
# 3    -0.018113  0.634868
# 4    -0.505933 -0.698943
# ...        ...       ...
# 3213 -1.091318 -1.114032
# 3214 -1.192634 -0.053770
# 3215  1.021319  0.328967
# 3216  0.507232 -0.545694
# 3217 -0.787368 -0.005172
#
# [3218 rows x 8 columns]

# %% [markdown]
# # Scaling the audio features of song provided by the user

# %%
# seaching spotify for song provided by the user
# todo: add artist to be more specific
user_song = "Fade to Black"
result = sp.search(q=user_song,limit=1)

# %%
# getting the id of a song
result["tracks"]["items"][0]["id"]
# Out:
# '0dqGfCMAGyDgpUAgLNOjWd'

# %%
# getting the audio features of a song using the song id
user_song_audio_features = sp.audio_features(result["tracks"]["items"][0]["id"])
user_song_audio_features
# Out:
# [{'danceability': 0.256,
#   'energy': 0.929,
#   'key': 7,
#   'loudness': -6.667,
#   'mode': 1,
#   'speechiness': 0.113,
#   'acousticness': 0.00311,
#   'instrumentalness': 0.201,
#   'liveness': 0.11,
#   'valence': 0.278,
#   'tempo': 113.47,
#   'type': 'audio_features',
#   'id': '0dqGfCMAGyDgpUAgLNOjWd',
#   'uri': 'spotify:track:0dqGfCMAGyDgpUAgLNOjWd',
#   'track_href': 'https://api.spotify.com/v1/tracks/0dqGfCMAGyDgpUAgLNOjWd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0dqGfCMAGyDgpUAgLNOjWd',
#   'duration_ms': 417227,
#   'time_signature': 4}]

# %%
# creating a Pandas dataframe with the audio features of the user song
user_song_df = pd.DataFrame(user_song_audio_features)    
user_song_df = user_song_df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

user_song_df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.256   0.929    -6.667        0.113       0.00311
#
#    instrumentalness  liveness  valence   tempo                      id  \
# 0             0.201      0.11    0.278  113.47  0dqGfCMAGyDgpUAgLNOjWd
#
#    duration_ms
# 0       417227

# %%
user_song_audio_features = user_song_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "liveness", "valence", "tempo"]]

# %%
# scaling the song provided by the user
user_song_audio_features_scaled = scaler.transform(user_song_audio_features)
user_song_audio_features_scaled
# Out:
# array([[-1.68554138,  1.1501986 ,  0.41712577,  0.62008648, -0.84779401,
#         -0.4689052 , -0.75359596, -0.21264562]])

# %%
# use kmeans.predict() to predict what cluster the song by user belongs to
label = kmeans.predict(user_song_audio_features_scaled)
label = int(label)

# %%
# including the "clusters", "id" and "duration_ms" columns to the scaled_songs_df
scaled_songs_df["clusters"] = clusters
scaled_songs_df = scaled_songs_df.join(songs_df[["id", "duration_ms"]])
scaled_songs_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1352\3712126729.py in <module>
#       1 # including the "clusters", "id" and "duration_ms" columns to the scaled_songs_df
#       2 scaled_songs_df["clusters"] = clusters
# ----> 3 scaled_songs_df = scaled_songs_df.join(songs_df[["id", "duration_ms"]])
#       4 scaled_songs_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9261         5  K1  A5   B1
#    9262         """
# -> 9263         return self._join_compat(
#    9264             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9265         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9292                     sort=sort,
#    9293                 )
# -> 9294             return merge(
#    9295                 self,
#    9296                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     716         join_index, left_indexer, right_indexer = self._get_join_info()
#     717
# --> 718         llabels, rlabels = _items_overlap_with_suffix(
#     719             self.left._info_axis, self.right._info_axis, self.suffixes
#     720         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2315
#    2316     if not lsuffix and not rsuffix:
# -> 2317         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2318
#    2319     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['id', 'duration_ms'], dtype='object')

# %%
# saving a csv file of the scaled_songs_df
scaled_songs_df.to_csv("scaled_songs_df.csv", index=False)

# %%
# including the "id" and "duration_ms" columns to the scaled_user_song_df
scaled_user_song_df = pd.DataFrame(user_song_audio_features_scaled, columns=["danceability", "energy", "loudness", "speechiness", "acousticness", "liveness", "valence", "tempo"])
scaled_user_song_df = scaled_user_song_df.join(user_song_df[["id", "duration_ms"]])
scaled_user_song_df.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  liveness  \
# 0     -1.685541  1.150199  0.417126     0.620086     -0.847794 -0.468905
#
#     valence     tempo                      id  duration_ms
# 0 -0.753596 -0.212646  0dqGfCMAGyDgpUAgLNOjWd       417227

# %%
scaled_songs_df.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  liveness  \
# 0     -0.773698  0.243009 -0.103995     0.088107     -0.856718 -0.345178
# 1     -1.314252  1.380714  0.801679     1.896837     -0.849668 -0.501182
# 2     -1.401614  0.915965  0.591065    -0.200682     -0.854738  0.187389
# 3     -0.609894  1.060967  0.882711     0.650485      0.197369  0.338014
# 4     -0.790078  1.153917  0.606434    -0.127725     -0.801553  0.359532
#
#     valence     tempo  clusters                      id  duration_ms
# 0 -0.565973  1.521344         4  3q9G9SvgdfE1fxlvoDIb20       167720
# 1 -1.065050  0.728899         4  47FyQCd3TYLrZ9TU6MPaWK       166707
# 2 -0.944972 -0.340822         1  6p8eFfPw3nQkf37aT3AkmK       438120
# 3 -0.018113  0.634868         4  2b9lp5A6CqSzwOrBfAFhof       296200
# 4 -0.505933 -0.698943         1  1s4Ie0cT6P73SRSfh3oyGW       291373

# %%
# creating a sample dataframe based on matching the clusters (could probably be done more efficiently)
sample_df = scaled_songs_df.loc[scaled_songs_df["clusters"]== label]
sample_df.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  liveness  \
# 2     -1.401614  0.915965  0.591065    -0.200682     -0.854738  0.187389
# 4     -0.790078  1.153917  0.606434    -0.127725     -0.801553  0.359532
# 5     -1.843885  1.395586  0.819842     1.532051     -0.855716 -0.377454
# 6     -1.423455  1.075839  0.679956    -0.547228     -0.851484  0.886720
# 8     -0.145782  0.938273  0.244059    -0.548748     -0.855121 -0.551749
#
#     valence     tempo  clusters                      id  duration_ms
# 2 -0.944972 -0.340822         1  6p8eFfPw3nQkf37aT3AkmK       438120
# 4 -0.505933 -0.698943         1  1s4Ie0cT6P73SRSfh3oyGW       291373
# 5 -1.660566 -1.125918         1  4fiOTntQKr24p07FvQDHZE       255187
# 6 -0.490924 -0.546011         1  1iGXvUsVVkYBas0Cniw6NB       432800
# 8  0.428430 -0.506907         1  6NwbeybX6TDtXlpXvnUOZC       516293

# %%
# taking the sample song
rec_song_df = sample_df.sample(1)
rec_song_df
# Out:
#       danceability    energy  loudness  speechiness  acousticness  liveness  \
# 1254       -0.0748  0.971735   0.51632    -0.273639     -0.312195 -0.242968
#
#        valence     tempo  clusters                      id  duration_ms
# 1254 -0.344578 -1.107034         1  7zwn1eykZtZ5LODrf7c0tS       153000

# %%
# isolate track_id
rec_song_id = rec_song_df["id"].to_string(index=False)
rec_song_id
# Out:
# '7zwn1eykZtZ5LODrf7c0tS'

# %%
# embed the Spotify player and passs it the rec_song_id
from IPython.display import IFrame

IFrame(src="https://open.spotify.com/embed/track/"+rec_song_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
       )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/7zwn1eykZtZ5LODrf7c0tS?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
